# %%
import pandas as pd

# %%
#series 1d 1 column , DataFrame 2d rxc

# %%
#series
pd.Series([1,2,3,4], name = "num")
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: num, dtype: int64

# %%
di={
    "name":["amaan","rahul","gopi","mohd","keshav","alok"],
    "age":[12,13,14,15,11,12]
}

df = pd.DataFrame(di)
df.head()
# Out:
#      name  age
# 0   amaan   12
# 1   rahul   13
# 2    gopi   14
# 3    mohd   15
# 4  keshav   11

# %%
# add column
marks=[67,89,67,98,90,81]
df.insert(1,"Marks", marks)
df.head()
# Out:
#      name  Marks  age
# 0   amaan     67   12
# 1   rahul     89   13
# 2    gopi     67   14
# 3    mohd     98   15
# 4  keshav     90   11

# %%
course = ["BCA","Btech","MBA","MCA","BCA","Btech"]
df["course"] = course
df.sample()
# Out:
#     name  Marks  age course
# 0  amaan     67   12    BCA

# %%
ID =[1,2,3,4,5,6]

# %%
do={
    "id":[1,2,3,4,5,6,7],
    "subjects":["maths","english","physics","computer",None,"GenAI","nlp"]

}

# %%
df1 = pd.DataFrame(do)
df1 = pd.DataFrame(do)
pd.merge(df, df1, on="id", how="inner")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 2
#       1 df1 = pd.DataFrame(do)
# ----> 2 pd.merge(df, df1, on="ID", how="inner")
#
# File c:\Users\Amaan\Desktop\PBEL_INTERNSHIP\PBEL 7\PBELSEVEN\Lib\site-packages\pandas\core\reshape\merge.py:385, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     371     return _cross_merge(
#     372         left_df,
#     373         right_df,
#    (...)    382         validate=validate,
#     383     )
#     384 else:
# --> 385     op = _MergeOperation(
#     386         left_df,
#     387         right_df,
#     388         how=how,
#     389         on=on,
#     390         left_on=left_on,
#     391         right_on=right_on,
#     392         left_index=left_index,
#     393         right_index=right_index,
#     394         sort=sort,
# ...

# %%
data.tail()

# %%
pd.read_csv("data/tipsdataset.csv)

# %%
df.info()

# %%
df.shape

# %%
df.describe()

# %%
df["gender"].value_counts()   #shows catagorical data

# %%
df.isnull().sum()

# %%
data

# %%
data.isnull().sum()

# %%
url=""

# %%
pd.read_csv(url)

# %%
df

# %%
df["gender"]=="Male"
smoker=df["smoker"]=="Yes"

# %%
df[Male & Yes].describe()

# %%
data.isnull().sum()

# %%
data['subject'].fillna("missing",inplace=True)

# %%
data["subject"]
