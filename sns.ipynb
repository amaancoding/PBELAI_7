# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
tips = pd.read_csv("DATA/tipsdataset.csv")

# %%
tips.sample()
# Out:
#     total_bill  tip gender smoker  day    time  size
# 28        21.7  4.3   Male     No  Sat  Dinner     2

# %%
sns.displot(data=tips, x="total_bill", col="time", kde=True)

# %%
sns.displot(data=tips, kind="ecdf", x="total_bill", col="time", hue="smoker", rug=True)

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()

# %%
tips.sample()
# Out:
#     total_bill  tip  gender  smoker  day  time  size
# 35       24.06  3.6       1       0    1     0     3

# %%
print(tips.dtypes)
# Out:
# total_bill    float64
# tip           float64
# gender          int64
# smoker          int64
# day             int64
# time            int64
# size            int64
# dtype: object

# %%
for i in tips.columns:                             # col name print(i)
    if str(tips[i].dtype) in ["object", "str"]:    #condition gender == true
        print(i)
        tips[i]=LE.fit_transform(tips[i])
# Out:
# gender
# smoker
# day
# time

# %%
tips.sample()
# Out:
#      total_bill  tip  gender  smoker  day  time  size
# 187       30.46  2.0       1       1    2     0     5

# %%
sns.heatmap(tips.corr())
# Out:
# <Axes: >

# %%
sns.pairplot(tips)
