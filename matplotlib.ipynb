# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("DATA/tipsdataset.csv")

# %%
data.sample()
# Out:
#      total_bill   tip  gender smoker  day    time  size
# 103       22.42  3.48  Female    Yes  Sat  Dinner     2

# %%
# line
plt.plot(data["size"])

# %%
data.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.plot(data["total_bill"])   # univariate analysis
plt.show()

# %%
plt.scatter(data["size"], data["tip"], s=data['total_bill'])
plt.show()    #bivariate analysis

# %%
plt.bar()   #bivariate num-cat
plt.bar(data["gender"], data["tip"])
# Out:
# <BarContainer object of 244 artists>

# %%
#plt.pie()   #univariate cat
plt.pie(data["tip"], labels=data["day"])
